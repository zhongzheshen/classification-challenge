# %% [markdown]
# # Spam Detector

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Retrieve the Data
#
# The data is located at [https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv](https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv)
#
# Dataset Source: [UCI Machine Learning Library](https://archive.ics.uci.edu/dataset/94/spambase)
#
# Import the data using Pandas. Display the resulting DataFrame to confirm the import was successful.

# %%
# Import the data
data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv")
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %% [markdown]
# ## Predict Model Performance
#
# You will be creating and comparing two models on this data: a Logistic Regression, and a Random Forests Classifier. Before you create, fit, and score the models, make a prediction as to which model you think will perform better. You do not need to be correct!
#
# Write down your prediction in the designated cells in your Jupyter Notebook, and provide justification for your educated guess.

# %% [markdown]
# *Replace the text in this markdown cell with your predictions, and be sure to provide justification for your guess.*

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Create the labels set `y` and features DataFrame `X`
X = data.drop('spam', axis=1)
y = data['spam']

# %%
# Split features and target

# %%
# Check the balance of the labels variable (`y`) by using the `value_counts` function.
y.value_counts()
# Out:
# spam
# 0    2788
# 1    1813
# Name: count, dtype: int64

# %%
# Split the data into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_train.head()
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 4576            0.00                0.0           0.00           0.0
# 4401            0.00                0.0           0.00           0.0
# 3707            0.17                0.0           0.17           0.0
# 2362            0.00                0.0           0.00           0.0
# 1537            0.00                0.0           0.00           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 4576           0.00             0.0               0.0                 0.0
# 4401           0.00             0.0               0.0                 0.0
# 3707           0.00             0.0               0.0                 0.0
# 2362           0.00             0.0               0.0                 0.0
# 1537           2.17             0.0               0.0                 0.0
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# ...

# %% [markdown]
# ## Scale the Features

# %% [markdown]
# Use the `StandardScaler` to scale the features data. Remember that only `X_train` and `X_test` DataFrames should be scaled.

# %%
from sklearn.preprocessing import StandardScaler

# Create the StandardScaler instance
# scaler = StandardScaler().fit(X_train, y_train)
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
X_train_scaled = scaler.fit_transform(X_train)

# %%
# Scale the training data
X_train_scaled
# Out:
# array([[-0.35811925, -0.16744248, -0.56071981, ..., -0.13974678,
#         -0.23023328, -0.37548424],
#        [-0.35811925, -0.16744248, -0.56071981, ..., -0.13640572,
#         -0.23023328, -0.46466704],
#        [ 0.21317665, -0.16744248, -0.22391235, ..., -0.01186062,
#          0.13008597,  1.25168127],
#        ...,
#        [-0.35811925, -0.16744248,  0.94500764, ..., -0.10138496,
#         -0.16385868, -0.06418577],
#        [-0.35811925, -0.16744248,  1.16294188, ..., -0.1351981 ,
#         -0.20178702, -0.01707033],
#        [-0.35811925, -0.16744248, -0.56071981, ..., -0.15524447,
#         -0.23971537, -0.42933046]])

# %% [markdown]
# ## Create and Fit a Logistic Regression Model
#
# Create a Logistic Regression model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Logistic Regression model and print the model score
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression()
lr_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
predictions = lr_model.predict(X_test)
results_df = pd.DataFrame({'prediction': predictions, 'Actual': y_test})
# results_df

# testing_predictions = lr_model.predict(X_test)
results_df = pd.DataFrame({
#    'Testing Data Predictions': testing_predictions,
    'Testing Data Predictions': predictions,
    'Testing Data Actual Targets': y_test})

# Review the predictions
results_df
# Out:
# C:\Users\des9231\AppData\Local\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
#       Testing Data Predictions  Testing Data Actual Targets
# 1351                         1                            1
# 1687                         1                            1
# 1297                         1                            1
# 2101                         1                            0
# 3920                         1                            0
# ...                        ...                          ...
# 1089                         1                            1
# 929                          1                            1
# 1545                         1                            1
# 4356                         0                            0
# 936                          1                            1
#
# [1151 rows x 2 columns]

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
print(f"Training Data Score: {lr_model.score(X_train_scaled, y_train)}")
# print(f"Testing Data Score: {lr_model.score(predictions, y_test)}")
# print(f"Testing Data Score: {lr_model.score(testing_predictions, y_test)}")
# Out:
# Training Data Score: 0.9295652173913044

# %% [markdown]
# ## Create and Fit a Random Forest Classifier Model
#
# Create a Random Forest Classifier model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier

rfc_model = RandomForestClassifier()
rfc_model.fit(X_train_scaled, y_train)

predictions = rfc_model.predict(X_test)
results_df = pd.DataFrame({'Prediction': predictions, 'Actual': y_test})

# testing_predictions = rfc_model.predict(X_test)
results_df = pd.DataFrame({
#    'Testing Data Predictions': testing_predictions,
    'Testing Data Predictions': predictions,
    'Testing Data Actual Targets': y_test})

results_df

# print(f"Training Data Score: {rfc_model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rfc_model.score(predictions, y_test)}")
# Out:
# C:\Users\des9231\AppData\Local\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 19
#      16 results_df
#      18 # print(f"Training Data Score: {rfc_model.score(X_train_scaled, y_train)}")
# ---> 19 print(f"Testing Data Score: {rfc_model.score(predictions, y_test)}")
#
# File ~\AppData\Local\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:764, in ClassifierMixin.score(self, X, y, sample_weight)
#     739 """
#     740 Return the mean accuracy on the given test data and labels.
#     741
#    (...)
#     760     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     761 """
#     762 from .metrics import accuracy_score
# ...

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
predictions = rfc_model.predict(X_test)
results_df = pd.DataFrame({'prediction': predictions, 'Actual': y_test})

testing_predictions = rfc_model.predict(X_test)
results_df = pd.DataFrame({
    'Testing Data Predictions': testing_predictions,
    'Testing Data Actual Targets': y_test})

# Review the predictions
results_df
# Out:
# C:\Users\des9231\AppData\Local\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\des9231\AppData\Local\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
#       Testing Data Predictions  Testing Data Actual Targets
# 1351                         0                            1
# 1687                         0                            1
# 1297                         0                            1
# 2101                         0                            0
# 3920                         0                            0
# ...                        ...                          ...
# 1089                         0                            1
# 929                          0                            1
# ...

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
print(f"Training Data Score: {rfc_model.score(X_train_scaled, y_train)}")
# Out:
# Training Data Score: 0.9997101449275362

# %% [markdown]
# ## Evaluate the Models
#
# Which model performed better? How does that compare to your prediction? Write down your results and thoughts in the following markdown cell.

# %% [markdown]
# *Replace the text in this markdown cell with your answers to these questions.*

# %%
# Random Forest Classifier Model (prediction accurate score is 0.9997101449275362) performed better 
# than Logistic Regression Model (prediction accurate score is 0.9295652173913044).
